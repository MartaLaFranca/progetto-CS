# %% [markdown]
# ### Anno Accademico 2020/21 Foundations of Computer Science
# #### Professore Gianluca Della Vedova
#
# La Franca Marta
#
# Mobilia Davide
#
# Risaro Alessandro

# %% [markdown]
# Importazione delle librerie utili ai fini di questo progetto

# %%
import pandas as pd
import numpy as np
import math
import re

# %% [markdown]
# Esplorazione e pulizia dei dataset

# %%
school_and_country=pd.read_table("/school_and_country_table.csv",sep=',')
school_and_country.head()
# Out:
#                              school_name                   country
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America

# %%
cwur=pd.read_table("cwurData.csv",sep=',')
cwur.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %% [markdown]
# Si eliminano gli acronimi presenti all'interno di parentesi

# %%
cwur['institution'] = cwur['institution'].str.replace('\s+\(\w+\-*\w*\s*\d*\)','', regex=True)

# %% [markdown]
# Si elimina il nome del campus dopo le università

# %%
cwur['institution'] = cwur['institution'].str.replace('\s+\-+\s+\w+\s*\d*\w*','', regex=True)

# %% [markdown]
# Si elimina il prefisso 'THE' e si procede eliminando anche lo spazio rimanente

# %%
cwur['institution'] = cwur['institution'].str.replace('^The','', regex=True)
cwur['institution'] = cwur['institution'].str.replace('^\s','', regex=True)

# %%
edu_attainment=pd.read_table("educational_attainment_supplementary_data.csv",sep=',')
edu_attainment.head()
# Out:
#   country_name                                        series_name  1985  1986  \
# 0  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.33   NaN
# 1  Afghanistan  Barro-Lee: Average years of primary schooling,...  1.03   NaN
# 2  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.83   NaN
# 3  Afghanistan  Barro-Lee: Average years of primary schooling,...  2.34   NaN
# 4  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.54   NaN
#
#    1987  1990  1991  1992  1993  1995  ...  2005  2006  2007  2008  2009  \
# 0   NaN  0.44   NaN   NaN   NaN  0.57  ...  0.86   NaN   NaN   NaN   NaN
# 1   NaN  1.26   NaN   NaN   NaN  1.54  ...  2.18   NaN   NaN   NaN   NaN
# 2   NaN  0.95   NaN   NaN   NaN  1.26  ...  1.01   NaN   NaN   NaN   NaN
# 3   NaN  2.22   NaN   NaN   NaN  2.37  ...  2.26   NaN   NaN   NaN   NaN
# 4   NaN  0.92   NaN   NaN   NaN  0.94  ...  2.00   NaN   NaN   NaN   NaN
#
#    2010  2011  2012  2013  2015
# ...

# %%
shanghai=pd.read_table("shanghaiData.csv",sep=',')
shanghai.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %% [markdown]
# Si portano le università del dataset shanghai ad un formato comune

# %%
shanghai['university_name'] = shanghai['university_name'].str.replace('Aix Marseille University', 'Aix-Marseille University', regex =True)
shanghai['university_name'] = shanghai['university_name'].str.replace('Arizona State University - Tempe', 'Arizona State University', regex =True)
shanghai['university_name'] = shanghai['university_name'].str.replace('Ecole Normale Superieure - Lyon','Ecole Normale Superieure de Lyon', regex= True)
shanghai['university_name'] = shanghai['university_name'].str.replace('Scuola Normale Superiore - Pisa','Scuola Normale Superiore di Pisa', regex= True)
shanghai['university_name'] = shanghai['university_name'].str.replace('Queen Mary, U. of London','Queen Mary, University of London', regex= True)
shanghai['university_name'] = shanghai['university_name'].str.replace('Royal Holloway, U. of London','Royal Holloway, University of London', regex= True)
shanghai['university_name'] = shanghai['university_name'].str.replace('Texas A & M University','Texas A&M University', regex= True)

# %% [markdown]
# Si elimina il prefisso 'THE' e si procede eliminando anche lo spazio rimanente

# %%
shanghai['university_name'] = shanghai['university_name'].str.replace('^The','', regex=True)
shanghai['university_name'] = shanghai['university_name'].str.replace('^\s','', regex=True) #si elimina lo spazio rimanente

# %% [markdown]
# Si elimina  il nome del campus dopo le università

# %%
shanghai['university_name'] = shanghai['university_name'].str.replace('\s+\-+\s+\w+\s*\d*\w*','', regex=True)

# %% [markdown]
# Si eliminano gli acronimi presenti all'interno di parentesi

# %%
shanghai['university_name'] = shanghai['university_name'].str.replace('\s+\(\w+\-*\w*\s*\d*\)','', regex=True)

# %%
times=pd.read_table("timesData.csv",sep=',')
times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %% [markdown]
# Si notano alcuni typos all'interno della colonna 'country'

# %%
times['country'].unique()
# Out:
# array(['United States of America', 'United Kingdom', 'Switzerland',
#        'Canada', 'Hong Kong', 'Japan', 'South Korea', 'Singapore',
#        'Australia', 'China', 'France', 'Sweden', 'Germany',
#        'Republic of Ireland', 'Finland', 'Taiwan', 'South Africa',
#        'Turkey', 'Netherlands', 'Belgium', 'Denmark', 'Norway', 'Spain',
#        'New Zealand', 'Egypt', 'Austria', 'Israel', 'Brazil', 'Italy',
#        'Russian Federation', 'Greece', 'Iceland', 'Czech Republic',
#        'India', 'Poland', 'Iran', 'Portugal', 'Thailand', 'Chile',
#        'Estonia', 'Saudi Arabia', 'Mexico', 'Colombia', 'Macau',
#        'Morocco', 'Luxembourg', 'Unisted States of America', 'Cyprus',
#        'Unted Kingdom', 'Uganda', 'Malaysia', 'Lebanon', 'Romania',
#        'Slovenia', 'Pakistan', 'Hungary', 'United Arab Emirates',
#        'Belarus', 'Serbia', 'Slovakia', 'Bangladesh', 'Ghana', 'Nigeria',
#        'Indonesia', 'Jordan', 'Latvia', 'Kenya', 'Argentina', 'Qatar',
# ...

# %%
times['country']=times['country'].str.replace('Unted Kingdom', 'United Kingdom')

# %%
times['country']=times['country'].str.replace('Unisted States of America','United States of America')

# %% [markdown]
# Si eliminano gli acronimi presenti all'interno delle parentesi

# %%
times['university_name'] = times['university_name'].str.replace('\s+\(\w+\-*\w*\s*\d*\)','', regex=True)

# %% [markdown]
# Si elimina il nome del campus dopo le università

# %%
times['university_name'] = times['university_name'].str.replace('\s+\-+\s+\w+\s*\d*\w*','', regex=True) #mettere * dopo gli \s??

# %% [markdown]
# Si elimina il prefisso 'THE' e si procede eliminando anche lo spazio rimanente

# %%
times['university_name'] = times['university_name'].str.replace('^The','', regex=True)
times['university_name'] = times['university_name'].str.replace('^\s','', regex=True) #si elimina lo spazio rimanente

# %% [markdown]
# ## 1. For each university, extract from the times dataset the most recent and the least recent data, obtaining two separate dataframes¶

# %% [markdown]
# Viene creato il dataset times_min per immagazzinare i dati meno recenti (viene usata la funzione loc in quanto si accede ai dati tramite una label specifico)

# %%
times_min=times.loc[times.groupby('university_name')['year'].idxmin()]
times_min
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 501     301-350                        Aalborg University         Denmark
# 502     301-350                          Aalto University         Finland
# 166         167                         Aarhus University         Denmark
# 476     276-300                    Aberystwyth University  United Kingdom
# ...         ...                                       ...             ...
# 41           42                  École Normale Supérieure          France
# 99          100          École Normale Supérieure de Lyon          France
# 38           39                       École Polytechnique          France
# 47           48  École Polytechnique Fédérale de Lausanne     Switzerland
# 2134    301-350                         Örebro University          Sweden
#
#       teaching international  research  citations income total_score  \
# ...

# %% [markdown]
# Si crea il dataset times_max con i dati più recenti

# %%
times_max=times.loc[times.groupby('university_name')['year'].idxmax()]
times_max
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
# ...         ...                                       ...             ...
# 1856         54                  École Normale Supérieure          France
# 2013    201-250          École Normale Supérieure de Lyon          France
# 1904       =101                       École Polytechnique          France
# 1833         31  École Polytechnique Fédérale de Lausanne     Switzerland
# 2134    301-350                         Örebro University          Sweden
#
#       teaching international  research  citations income total_score  \
# ...

# %% [markdown]
# ## 2. For each university, compute the improvement in income between the least recent and the most recent data points

# %% [markdown]
# Trasformo in float l'attributo income, poichè è di tipo object

# %%
times_max.dtypes['income']
# Out:
# dtype('O')

# %%
times_min.dtypes['income']
# Out:
# dtype('O')

# %%
times_max['income']=pd.to_numeric(times_max['income'],errors='coerce')
times_min['income']=pd.to_numeric(times_min['income'],errors='coerce')

# %%
times_max.dtypes['income']
# Out:
# dtype('float64')

# %% [markdown]
# Si crea un nuovo dataset 'differenza' che contenga le due colonne 'income' fondendo i due dataset attraverso 'university_name'

# %%
differenza=pd.merge(times_min[['university_name','income']],times_max[['university_name','income']],on='university_name',suffixes=("_min","_max"))
differenza.head()
# Out:
#                             university_name  income_min  income_max
# 0  AGH University of Science and Technology         NaN         NaN
# 1                        Aalborg University        36.4        43.7
# 2                          Aalto University        61.9        61.6
# 3                         Aarhus University        61.5        68.3
# 4                    Aberystwyth University        35.5        31.3

# %% [markdown]
# Si crea una nuova colonna che computi la differenza

# %%
differenza['differenza_income']=differenza['income_max']-differenza['income_min']
differenza
# Out:
#                               university_name  income_min  income_max  \
# 0    AGH University of Science and Technology         NaN         NaN
# 1                          Aalborg University        36.4        43.7
# 2                            Aalto University        61.9        61.6
# 3                           Aarhus University        61.5        68.3
# 4                      Aberystwyth University        35.5        31.3
# ..                                        ...         ...         ...
# 813                  École Normale Supérieure        30.7        37.1
# 814          École Normale Supérieure de Lyon        26.1        31.7
# 815                       École Polytechnique         NaN        82.3
# 816  École Polytechnique Fédérale de Lausanne        38.0        65.4
# 817                         Örebro University        29.8        29.8
#
#      differenza_income
# 0                  NaN
# 1                  7.3
# 2                 -0.3
# 3                  6.8
# ...

# %% [markdown]
# ## 3. Find the university with the largest increase computed in the previous point

# %%
differenza[differenza["differenza_income"]>=differenza["differenza_income"].max()]
# Out:
#     university_name  income_min  income_max  differenza_income
# 429      TU Dresden        31.9        99.7               67.8

# %% [markdown]
# ## 4. For each ranking, consider only the most recent data point. For each university, compute the maximum difference between the rankings (e.g. for Aarhus University the value is 122-73=49). Notice that some rankings are expressed as a range

# %% [markdown]
# Si isolano i datapoints più recenti per ogni dataset di interesse: shanghai,cwur e times

# %%
shanghai_max=shanghai.loc[shanghai.groupby('university_name')['year'].idxmax()]
shanghai_max.head()
# Out:
#      world_rank                       university_name national_rank  \
# 4697    301-400                    Aalborg University             5
# 4797    401-500                      Aalto University           4-6
# 4469         73                     Aarhus University             2
# 4497    101-150              Aix-Marseille University           5-6
# 4798    401-500  Aristotle University of Thessaloniki             2
#
#       total_score  alumni  award  hici    ns   pub   pcp  year
# 4697          NaN     0.0    0.0  11.2   4.6  30.4  16.8  2015
# 4797          NaN     0.0    0.0   0.0  10.4  33.4  17.0  2015
# 4469         27.3    11.5   22.1  12.3  25.8  51.8  31.0  2015
# 4497          NaN    13.6    0.0  15.2  20.3  50.1  27.6  2015
# 4798          NaN     0.0    0.0   4.9   1.5  34.0  16.8  2015

# %%
cwur_max=cwur.loc[cwur.groupby('institution')['year'].idxmax()]
cwur_max.head()
# Out:
#       world_rank                               institution         country  \
# 1981         782  AGH University of Science and Technology          Poland
# 1764         565                        Aalborg University         Denmark
# 1620         421                          Aalto University         Finland
# 1321         122                         Aarhus University         Denmark
# 2013         814                    Aberystwyth University  United Kingdom
#
#       national_rank  quality_of_education  alumni_employment  \
# 1981              4                   267                279
# 1764              5                   367                439
# 1620              4                   367                224
# 1321              2                   310                165
# 2013             59                   367                567
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# ...

# %% [markdown]
# times_max è stato precedentemente computato

# %%
times_max.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
#
#       teaching international  research  citations  income total_score  \
# 2405      14.2          17.9       3.7       35.7     NaN           -
# 2003      25.1          71.0      28.4       73.8    43.7           -
# 2056      31.1          65.4      32.8       62.1    61.6           -
# 1908      36.9          76.8      50.7       79.8    68.3        57.7
# 2105      21.6          72.2      18.9       67.2    31.3           -
#
#      num_students  student_staff_ratio international_students  \
# ...

# %% [markdown]
# Si effettua una merge intermedia tra il dataset shanghai_max e il dataset times_max su 'university_name'

# %%
fuso=pd.merge(shanghai_max[['university_name','world_rank']],times_max[['university_name','world_rank']],on='university_name',suffixes=("_shanghai",""))
fuso
# Out:
#                           university_name world_rank_shanghai world_rank
# 0                      Aalborg University             301-400    201-250
# 1                        Aalto University             401-500    251-300
# 2                       Aarhus University                  73       =106
# 3                Aix-Marseille University             101-150    251-300
# 4    Aristotle University of Thessaloniki             401-500    601-800
# ..                                    ...                 ...        ...
# 424                       Yale University                  11         12
# 425                    Yeshiva University             201-300       =164
# 426                     Yonsei University             201-300    301-350
# 427                       York University             401-500    301-350
# 428                   Zhejiang University             101-150    251-300
#
# [429 rows x 3 columns]

# %% [markdown]
# Si rinomina la colonna 'university_name' per chiarezza

# %%
cwur_max.rename(columns={'institution':'university_name'}, inplace=True)
cwur_max.head()
# Out:
#       world_rank                           university_name         country  \
# 1981         782  AGH University of Science and Technology          Poland
# 1764         565                        Aalborg University         Denmark
# 1620         421                          Aalto University         Finland
# 1321         122                         Aarhus University         Denmark
# 2013         814                    Aberystwyth University  United Kingdom
#
#       national_rank  quality_of_education  alumni_employment  \
# 1981              4                   267                279
# 1764              5                   367                439
# 1620              4                   367                224
# 1321              2                   310                165
# 2013             59                   367                567
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# ...

# %% [markdown]
# Si effettua una merge tra fuso e cwur_max sulla colonna 'university_name'

# %%
ranks=pd.merge(fuso,cwur_max[['university_name','world_rank']],on='university_name',suffixes=("_times","_cwur"))
ranks
# Out:
#                           university_name world_rank_shanghai  \
# 0                      Aalborg University             301-400
# 1                        Aalto University             401-500
# 2                       Aarhus University                  73
# 3                Aix-Marseille University             101-150
# 4    Aristotle University of Thessaloniki             401-500
# ..                                    ...                 ...
# 403                       Yale University                  11
# 404                    Yeshiva University             201-300
# 405                     Yonsei University             201-300
# 406                       York University             401-500
# 407                   Zhejiang University             101-150
#
#     world_rank_times  world_rank_cwur
# 0            201-250              565
# 1            251-300              421
# 2               =106              122
# 3            251-300              206
# ...

# %% [markdown]
# Si indaga la presenza di eventuali difformità nei dati

# %%
ranks['world_rank_cwur'].unique()
# Out:
# array([565, 421, 122, 206, 459,  97, 549, 179, 241, 304, 568, 521, 349,
#        464, 698, 326,  66, 274,  83, 796,  12, 788, 201, 593,  61, 105,
#        387, 402, 563, 270, 418, 627, 220, 628, 373, 207, 483, 271,   6,
#        228, 417,  10, 595, 286, 305,  44, 579, 255, 258,  28, 261, 477,
#        651, 348,  84, 390, 526, 583, 322, 620, 605, 252, 195, 414, 202,
#        113,  80, 119, 670, 613, 634, 192, 410,   1,  23, 290, 178, 354,
#        319, 719, 400, 448, 614, 187, 623, 451, 541, 391,  16, 188, 465,
#        457, 353, 213,  71,  34, 571, 995, 569, 320, 144, 115, 419,  17,
#        401, 307, 100, 645, 426, 229, 264, 108, 694, 332, 117, 225, 449,
#          3, 658,  42, 150, 297, 303, 265, 611, 118, 790, 145, 556, 829,
#        486, 125, 244, 135, 334, 564, 226, 386,  57, 407,  65, 301, 761,
#        519,  18, 212, 468, 232, 275,  22, 243, 460, 245, 656, 631, 260,
#        474, 598,  45,  56, 165, 370, 653, 440, 375, 661,   9, 452, 209,
# ...

# %%
ranks['world_rank_times'].unique()
# Out:
# array(['201-250', '251-300', '=106', '601-800', '189', '501-600', '52',
#        '146', '301-350', '401-500', '=190', '64', '=185', '51', '1',
#        '=182', '22', '=133', '=138', '15', '18', '=104', '=65', '351-400',
#        '20', '70', '=176', '=90', '=94', '41', '118', '6', '178', '59',
#        '11', '28', '148', '=88', '130', '67', '5', '38', '=99', '350-400',
#        '73', '55', '=167', '26', '30', '=196', '25', '42', '116', '=164',
#        '7', '98', '=110', '=125', '=101', '129', '112', '85', '3', '136',
#        '153', '226-250', '=47', '=127', '14', '=172', '=149', '137', '58',
#        '163', '174', '=120', '119', '69', '34', '13', '=44', '16', '=39',
#        '=144', '4', '10', '=82', '24', '=123', '93', '=131', '=76',
#        '=180', '74', '175', '157', '=56', '117', '33', '=161', '=113',
#        '63', '108', '143', '135', '2', '17', '79', '=60', '=158', '97',
#        '68', '86', '140', '46', '43', '19', '142', '147', '80', '32',
# ...

# %%
ranks['world_rank_shanghai'].unique()
# Out:
# array(['301-400', '401-500', '73', '101-150', '93', '77', '201-300',
#        '403-510', '75', '7', '151-200', '61', '8', '13', '31', '402-501',
#        '71', '1', '67', '16', '48', '26', '82', '3', '64', '96', '99',
#        '402-503', '27', '85', '6', '84', '2', '18', '90', '87', '97',
#        '66', '40', '4', '57', '50', '12', '14', '38', '5', '9', '35',
#        '47', '83', '58', '41', '43', '44', '39', '10', '17', '49', '37',
#        '21', '25', '92', '15', '54', '56', '98', '53', '11'], dtype=object)

# %% [markdown]
# Si eliminano gli ' = ' presenti nella colonna 'world_rank_times'

# %%
ranks['world_rank_times']=ranks['world_rank_times'].str.replace('\=', '', regex=True)

# %% [markdown]
# Si isolano i range del dataset 'times' in una nuova colonna denominata 'range_times'

# %%
range_re=re.compile("(\d+)-(\d+)")    
ranks['ranges_times']=ranks["world_rank_times"][ranks['world_rank_times'].str.match(range_re)]
ranks
# Out:
#                           university_name world_rank_shanghai  \
# 0                      Aalborg University             301-400
# 1                        Aalto University             401-500
# 2                       Aarhus University                  73
# 3                Aix-Marseille University             101-150
# 4    Aristotle University of Thessaloniki             401-500
# ..                                    ...                 ...
# 403                       Yale University                  11
# 404                    Yeshiva University             201-300
# 405                     Yonsei University             201-300
# 406                       York University             401-500
# 407                   Zhejiang University             101-150
#
#     world_rank_times  world_rank_cwur ranges_times
# 0            201-250              565      201-250
# 1            251-300              421      251-300
# 2                106              122          NaN
# ...

# %% [markdown]
# Si isolano i range del dataset 'shanghai' in una nuova colonna denominata 'range_shanghai'

# %%
range_re=re.compile("(\d+)-(\d+)")     
ranks['ranges_shanghai']=ranks["world_rank_shanghai"][ranks['world_rank_shanghai'].str.match(range_re)]
ranks
# Out:
#                           university_name world_rank_shanghai  \
# 0                      Aalborg University             301-400
# 1                        Aalto University             401-500
# 2                       Aarhus University                  73
# 3                Aix-Marseille University             101-150
# 4    Aristotle University of Thessaloniki             401-500
# ..                                    ...                 ...
# 403                       Yale University                  11
# 404                    Yeshiva University             201-300
# 405                     Yonsei University             201-300
# 406                       York University             401-500
# 407                   Zhejiang University             101-150
#
#     world_rank_times  world_rank_cwur ranges_times ranges_shanghai
# 0            201-250              565      201-250         301-400
# 1            251-300              421      251-300         401-500
# ...

# %% [markdown]
# Si estraggono i due estremi del range relativi al dataset 'times'

# %%
ranks['range1']=ranks['ranges_times'].str.replace('(\d+)-(\d+)', r"\1", regex=True)
ranks['range2']=ranks['ranges_times'].str.replace('(\d+)-(\d+)', r"\2", regex=True)

# %% [markdown]
# Si trova la media tra i due vertici di ogni range del dataset

# %%
ranks["world_rank_times"]=np.where(ranks["ranges_times"].isnull(),ranks["world_rank_times"],(pd.to_numeric(ranks['range1'])+pd.to_numeric(ranks['range2']))/2)

# %% [markdown]
# Si estraggono i due estremi del range relativi al dataset 'shanghai'

# %%
ranks['range1']=ranks['ranges_shanghai'].str.replace('(\d+)-(\d+)', r"\1", regex=True)
ranks['range2']=ranks['ranges_shanghai'].str.replace('(\d+)-(\d+)', r"\2", regex=True)

# %% [markdown]
# Si trova la media tra i due vertici di ogni range del dataset

# %%
ranks["world_rank_shanghai"]=np.where(ranks["ranges_shanghai"].isnull(),ranks["world_rank_shanghai"],(pd.to_numeric(ranks['range2'])+pd.to_numeric(ranks['range1']))/2)

# %%
ranks
# Out:
#                           university_name world_rank_shanghai  \
# 0                      Aalborg University               350.5
# 1                        Aalto University               450.5
# 2                       Aarhus University                  73
# 3                Aix-Marseille University               125.5
# 4    Aristotle University of Thessaloniki               450.5
# ..                                    ...                 ...
# 403                       Yale University                  11
# 404                    Yeshiva University               250.5
# 405                     Yonsei University               250.5
# 406                       York University               450.5
# 407                   Zhejiang University               125.5
#
#     world_rank_times  world_rank_cwur ranges_times ranges_shanghai range1  \
# 0              225.5              565      201-250         301-400    301
# ...

# %% [markdown]
# Si eliminano le colonne non più influenti

# %%
ranks.drop(columns=['ranges_times', 'ranges_shanghai',"range2",'range1'],axis=1,inplace=True)

# %% [markdown]
# Si trasforma in float

# %%
ranks.dtypes['world_rank_shanghai']
# Out:
# dtype('O')

# %%
ranks.dtypes['world_rank_times']
# Out:
# dtype('O')

# %%
ranks['world_rank_shanghai']=pd.to_numeric(ranks['world_rank_shanghai'])
ranks['world_rank_times']=pd.to_numeric(ranks['world_rank_times'])

# %%
ranks.dtypes['world_rank_times']
# Out:
# dtype('float64')

# %% [markdown]
# Si trova la differenza richiesta

# %%
ranks["max_diff_rank"]=ranks.max(axis=1)-ranks.min(axis=1)    #axis=1 per la differenza su ogni riga, non sulle colonne(in verticale)

# %%
ranks
# Out:
#                           university_name  world_rank_shanghai  \
# 0                      Aalborg University                350.5
# 1                        Aalto University                450.5
# 2                       Aarhus University                 73.0
# 3                Aix-Marseille University                125.5
# 4    Aristotle University of Thessaloniki                450.5
# ..                                    ...                  ...
# 403                       Yale University                 11.0
# 404                    Yeshiva University                250.5
# 405                     Yonsei University                250.5
# 406                       York University                450.5
# 407                   Zhejiang University                125.5
#
#      world_rank_times  world_rank_cwur  max_diff_rank
# 0               225.5              565          339.5
# 1               275.5              421          175.0
# ...

# %% [markdown]
# Controlliamo che la Aarhus University abbia effettivamente il valore 49 come differenza

# %%
ranks[ranks['university_name']=='Aarhus University']
# Out:
#      university_name  world_rank_shanghai  world_rank_times  world_rank_cwur  \
# 2  Aarhus University                 73.0             106.0              122
#
#    max_diff_rank
# 2           49.0

# %% [markdown]
# ## 5. Consider only the most recent data point of the times dataset. Compute the number of male and female students for each country.

# %% [markdown]
# Si considera il dataset times_max precedentemente trovato

# %%
times_max.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
#
#       teaching international  research  citations  income total_score  \
# 2405      14.2          17.9       3.7       35.7     NaN           -
# 2003      25.1          71.0      28.4       73.8    43.7           -
# 2056      31.1          65.4      32.8       62.1    61.6           -
# 1908      36.9          76.8      50.7       79.8    68.3        57.7
# 2105      21.6          72.2      18.9       67.2    31.3           -
#
#      num_students  student_staff_ratio international_students  \
# ...

# %% [markdown]
# Si elimina la virgola presente nella colonna 'num_students'

# %%
times_max['num_students']=times_max['num_students'].str.replace('\,', '', regex=True)  #elimino la virgola per evitare problemi nella trasformazione in float
times_max.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
#
#       teaching international  research  citations  income total_score  \
# 2405      14.2          17.9       3.7       35.7     NaN           -
# 2003      25.1          71.0      28.4       73.8    43.7           -
# 2056      31.1          65.4      32.8       62.1    61.6           -
# 1908      36.9          76.8      50.7       79.8    68.3        57.7
# 2105      21.6          72.2      18.9       67.2    31.3           -
#
#      num_students  student_staff_ratio international_students  \
# ...

# %% [markdown]
# Si trasformano i valori presenti nella colonna 'num_students' in float

# %%
times_max['num_students']=pd.to_numeric(times_max['num_students'],errors='coerce')

# %% [markdown]
# Si indagano i valori presenti nella colonna female_male_ratio

# %%
times_max['female_male_ratio'].unique()
# Out:
# array(['-', '48 : 52', '32 : 68', '54 : 46', '71 : 29', '61 : 39',
#        '33 : 67', '46 : 54', '63 : 37', '17 : 83', '60 : 40', '51 : 49',
#        '34 : 66', nan, '78 : 22', '36 : 64', '52 : 48', '50 : 50',
#        '53 : 47', '47 : 53', '58 : 42', '59 : 41', '56 : 44', '67 : 33',
#        '55 : 45', '23 : 77', '69 : 31', '49 : 51', '57 : 43', '22 : 78',
#        '27 : 73', '70 : 30', '43 : 57', '39 : 61', '66 : 34', '30 : 70',
#        '42 : 58', '64 : 36', '62 : 38', '19 : 81', '37 : 63', '45 : 55',
#        '41 : 59', '26 : 74', '31 : 69', '100 : 0', '24 : 76', '35 : 65',
#        '25 : 75', '29 : 71', '65 : 35', '16 : 84', '18 : 82', '14 : 86',
#        '13 : 87', '15 : 85', '44 : 56', '20 : 80', '11 : 89', '28 : 72',
#        '38 : 62', '40 : 60', '12 : 88', '1 : 99', '74 : 26', '77 : 23',
#        '9 : 91', '76 : 24', '21 : 79', '68 : 32'], dtype=object)

# %% [markdown]
# Si eliminano i valori nulli

# %%
times_max.dropna(subset=['num_students'], axis=0, inplace=True)
times_max.dropna(subset=['female_male_ratio'], axis=0, inplace=True)

# %% [markdown]
# Si "dividono" i numeri della ratio

# %%
times_max['female_ratio']=times_max['female_male_ratio'].str.extract(r'(^[0-9][0-9]?[0-9]?)')  #? match 0 o 1 volta il precedente

# %%
times_max['male_ratio']=times_max['female_male_ratio'].str.extract(r'([0-9][0-9]?$)')

# %%
times_max.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
#
#       teaching international  research  citations  income total_score  \
# 2405      14.2          17.9       3.7       35.7     NaN           -
# 2003      25.1          71.0      28.4       73.8    43.7           -
# 2056      31.1          65.4      32.8       62.1    61.6           -
# 1908      36.9          76.8      50.7       79.8    68.3        57.7
# 2105      21.6          72.2      18.9       67.2    31.3           -
#
#       num_students  student_staff_ratio international_students  \
# ...

# %% [markdown]
# Si osserva che 'female_ratio' e 'male_ratio' sono di tipo Object

# %%
times_max.dtypes['female_ratio']
# Out:
# dtype('O')

# %%
times_max.dtypes['male_ratio']
# Out:
# dtype('O')

# %% [markdown]
# Si trasformano i valori in float, e si trova il corrispondente numero di femmine e maschi

# %%
times_max['female_ratio']=pd.to_numeric(times_max['female_ratio'],errors='coerce')

# %%
times_max['num_female']=(times_max['female_ratio']/100)*times_max['num_students']

# %%
times_max['male_ratio']=pd.to_numeric(times_max['male_ratio'],errors='coerce')

# %%
times_max['num_male']=(times_max['male_ratio']/100)*times_max['num_students']

# %% [markdown]
# Si raggruppa in base alla colonna 'country'

# %%
times_max.groupby('country',as_index=False)['num_female'].sum()
# Out:
#                      country  num_female
# 0                  Argentina    67191.26
# 1                  Australia   391735.88
# 2                    Austria    68364.08
# 3                 Bangladesh    21323.44
# 4                    Belarus    20219.07
# ..                       ...         ...
# 65                    Uganda    18670.00
# 66                   Ukraine    17846.00
# 67      United Arab Emirates     9516.44
# 68            United Kingdom   711813.62
# 69  United States of America  1601453.63
#
# [70 rows x 2 columns]

# %%
times_max.groupby('country',as_index=False)['num_male'].sum()
# Out:
#                      country    num_male
# 0                  Argentina    41181.74
# 1                  Australia   321640.12
# 2                    Austria    66112.92
# 3                 Bangladesh    41392.56
# 4                    Belarus     9083.93
# ..                       ...         ...
# 65                    Uganda    18670.00
# 66                   Ukraine    19250.00
# 67      United Arab Emirates     4930.56
# 68            United Kingdom   613028.38
# 69  United States of America  1556321.37
#
# [70 rows x 2 columns]

# %% [markdown]
# ## 6. Find the universities where the ratio between female and male is below the average ratio (computed over all universities)

# %%
times_max.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
#
#       teaching international  research  citations  income total_score  \
# 2405      14.2          17.9       3.7       35.7     NaN           -
# 2003      25.1          71.0      28.4       73.8    43.7           -
# 2056      31.1          65.4      32.8       62.1    61.6           -
# 1908      36.9          76.8      50.7       79.8    68.3        57.7
# 2105      21.6          72.2      18.9       67.2    31.3           -
#
#       num_students  student_staff_ratio international_students  \
# ...

# %% [markdown]
# Si calcola il rapporto tra female_ratio e male_ratio

# %%
times_max['ratio_num']=times_max['female_ratio']/times_max['male_ratio']

# %% [markdown]
# Si nota la presenza di un valore inf dato dal rapporto 100:0

# %%
times_max['ratio_num'].unique()
# Out:
# array([       nan, 0.92307692, 0.47058824, 1.17391304, 2.44827586,
#        1.56410256, 0.49253731, 0.85185185, 1.7027027 , 0.20481928,
#        1.5       , 1.04081633, 0.51515152, 3.54545455, 0.5625    ,
#        1.08333333, 1.        , 1.12765957, 0.88679245, 1.38095238,
#        1.43902439, 1.27272727, 2.03030303, 1.22222222, 0.2987013 ,
#        2.22580645, 0.96078431, 1.3255814 , 0.28205128, 0.36986301,
#        2.33333333, 0.75438596, 0.63934426, 1.94117647, 0.42857143,
#        0.72413793, 1.77777778, 1.63157895, 0.2345679 , 0.58730159,
#        0.81818182, 0.69491525, 0.35135135, 0.44927536,        inf,
#        0.31578947, 0.53846154, 0.33333333, 0.4084507 , 1.85714286,
#        0.19047619, 0.2195122 , 0.1627907 , 0.14942529, 0.17647059,
#        0.78571429, 0.25      , 0.12359551, 0.38888889, 0.61290323,
#        0.66666667, 0.13636364, 0.01010101, 2.84615385, 3.34782609,
#        0.0989011 , 3.16666667, 0.26582278, 2.125     ])

# %% [markdown]
# Si procede sostituendo il valore inf al valore 100, così da indicare un'università totalmente femminile

# %%
times_max["ratio"]=np.where(times_max['ratio_num']==math.inf,100,times_max["ratio_num"])

# %% [markdown]
# Si computa la media

# %%
times_max['ratio'].mean()
# Out:
# 1.2149571636836496

# %% [markdown]
# Si trovano le università desiderate

# %%
sotto_media = times_max[times_max['ratio'] < times_max['ratio'].mean()]
sotto_media
# Out:
#      world_rank                           university_name         country  \
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
# 2406    601-800                           Ajou University     South Korea
# ...         ...                                       ...             ...
# 2104    251-300                       Zhejiang University           China
# 1856         54                  École Normale Supérieure          France
# 2013    201-250          École Normale Supérieure de Lyon          France
# 1904       =101                       École Polytechnique          France
# 1833         31  École Polytechnique Fédérale de Lausanne     Switzerland
#
#       teaching international  research  citations  income total_score  \
# ...

# %% [markdown]
# ## 7. For each country, compute the fraction of the students in the country that are in one of the universities computed in the previous point (that is, the denominator of the ratio is the total number of students over all universities in the country).

# %%
times_max.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
#
#       teaching international  research  citations  income total_score  \
# 2405      14.2          17.9       3.7       35.7     NaN           -
# 2003      25.1          71.0      28.4       73.8    43.7           -
# 2056      31.1          65.4      32.8       62.1    61.6           -
# 1908      36.9          76.8      50.7       79.8    68.3        57.7
# 2105      21.6          72.2      18.9       67.2    31.3           -
#
#       num_students  student_staff_ratio international_students  \
# ...

# %% [markdown]
# Si calcola per ogni paese il numero totale degli studenti che appartengono alle università computate nel precedente punto (sotto la media)

# %%
numeratore=sotto_media.groupby('country',as_index=False)['num_students'].sum()
numeratore.head()
# Out:
#       country  num_students
# 0   Australia      295021.0
# 1     Austria       79242.0
# 2  Bangladesh       62716.0
# 3     Belgium      116129.0
# 4      Brazil      438476.0

# %% [markdown]
# Si calcola per ogni paese il numero totale degli studenti

# %%
denominatore=times_max.groupby('country',as_index=False)['num_students'].sum()
denominatore.head()
# Out:
#       country  num_students
# 0   Argentina      108373.0
# 1   Australia      713376.0
# 2     Austria      134477.0
# 3  Bangladesh       62716.0
# 4     Belarus       29303.0

# %% [markdown]
# Si uniscono i risultati in un solo dataset

# %%
parz_tot = pd.merge(numeratore, denominatore, on = 'country', suffixes=('_parz', '_tot'))
parz_tot.head()
# Out:
#       country  num_students_parz  num_students_tot
# 0   Australia           295021.0          713376.0
# 1     Austria            79242.0          134477.0
# 2  Bangladesh            62716.0           62716.0
# 3     Belgium           116129.0          169661.0
# 4      Brazil           438476.0          494251.0

# %% [markdown]
# Si aggiunge una colonna che computi la frazione richiesta

# %%
parz_tot['fraction']=parz_tot['num_students_parz']/parz_tot['num_students_tot']
parz_tot.head()
# Out:
#       country  num_students_parz  num_students_tot  fraction
# 0   Australia           295021.0          713376.0  0.413556
# 1     Austria            79242.0          134477.0  0.589261
# 2  Bangladesh            62716.0           62716.0  1.000000
# 3     Belgium           116129.0          169661.0  0.684477
# 4      Brazil           438476.0          494251.0  0.887152

# %% [markdown]
# ## 8. Read the file educational_attainment_supplementary_data.csv, discarding any row with missing country_name or series_name

# %%
edu_attainment
# Out:
#                                             country_name  \
# 0                                            Afghanistan
# 1                                            Afghanistan
# 2                                            Afghanistan
# 3                                            Afghanistan
# 4                                            Afghanistan
# ...                                                  ...
# 79050                                                NaN
# 79051                                                NaN
# 79052                                                NaN
# 79053  Data from database: Education Statistics: Educ...
# 79054                           Last Updated: 10/20/2015
#
#                                              series_name  1985  1986  1987  \
# 0      Barro-Lee: Average years of primary schooling,...  0.33   NaN   NaN
# 1      Barro-Lee: Average years of primary schooling,...  1.03   NaN   NaN
# ...

# %% [markdown]
# Si eliminano i valori nulli nelle colonne presenti nel parametro subset di dropna():

# %%
edu_attainment.dropna(subset = ['country_name','series_name'],inplace=True)

# %% [markdown]
# Si effettua un controllo

# %%
edu_attainment['country_name'].isnull().sum()
# Out:
# 0

# %%
edu_attainment['series_name'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## 9. From attainment build a dataframe with the same data, but with 4 columns: country_name, series_name, year, value

# %% [markdown]
# Si vogliono convertire il dataframe in un wide format in un dataframe in un formato long, ossia convertire le colonne rendendole dei valori di riga. Sarà inoltre necessario modificare il nome di colonna in year. Per poter svolgere tale compito, è sufficiente utilizzare la funzione .melt() adibita a tale scopo:

# %%
new_attainment=pd.melt(edu_attainment,id_vars=["country_name", "series_name"], var_name="year", 
        value_name="value")

# %%
new_attainment.head()
# Out:
#   country_name                                        series_name  year  value
# 0  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   0.33
# 1  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   1.03
# 2  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   0.83
# 3  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   2.34
# 4  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   0.54

# %% [markdown]
# ## 10. For each university, find the number of rankings in which they appear (it suffices to appear in one year for each ranking).

# %%
times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
cwur.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
shanghai.head()
# Out:
#   world_rank                        university_name national_rank  \
# 0          1                     Harvard University             1
# 1          2                University of Cambridge             1
# 2          3                    Stanford University             2
# 3          4     University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %% [markdown]
# Si crea un nuovo dataset contenente tutte le università presenti nel ranking times

# %%
unique_times=pd.DataFrame(times['university_name'].unique(),columns=['university'])
unique_times
# Out:
#                                 university
# 0                       Harvard University
# 1       California Institute of Technology
# 2    Massachusetts Institute of Technology
# 3                      Stanford University
# 4                     Princeton University
# ..                                     ...
# 813                      Xidian University
# 814                    Yeungnam University
# 815            Yıldız Technical University
# 816               Yokohama City University
# 817           Yokohama National University
#
# [818 rows x 1 columns]

# %% [markdown]
# Si crea un nuovo dataset contenente tutte le università presenti nel ranking shanghai

# %%
unique_shanghai=pd.DataFrame(shanghai['university_name'].unique(),columns=['university'])
unique_shanghai
# Out:
#                                 university
# 0                       Harvard University
# 1                  University of Cambridge
# 2                      Stanford University
# 3       University of California, Berkeley
# 4    Massachusetts Institute of Technology
# ..                                     ...
# 636             Capital Medical University
# 637    Queensland University of Technology
# 638        Sharif University of Technology
# 639                    University of Genoa
# 640                  University of Seville
#
# [641 rows x 1 columns]

# %% [markdown]
# Si crea un nuovo dataset contenente tutte le università presenti nel ranking cwur

# %%
unique_cwur=pd.DataFrame(cwur['institution'].unique(),columns=['university'])
unique_cwur
# Out:
#                                  university
# 0                        Harvard University
# 1     Massachusetts Institute of Technology
# 2                       Stanford University
# 3                   University of Cambridge
# 4        California Institute of Technology
# ...                                     ...
# 1016                    Shenzhen University
# 1017             Tianjin Medical University
# 1018                Babeș-Bolyai University
# 1019                Henan Normal University
# 1020          Southwest Jiaotong University
#
# [1021 rows x 1 columns]

# %% [markdown]
# Si crea un nuovo dataset concatenando i tre dataset precedentemente trovati

# %%
unione=pd.concat([unique_times,unique_shanghai,unique_cwur])
unione
# Out:
#                                  university
# 0                        Harvard University
# 1        California Institute of Technology
# 2     Massachusetts Institute of Technology
# 3                       Stanford University
# 4                      Princeton University
# ...                                     ...
# 1016                    Shenzhen University
# 1017             Tianjin Medical University
# 1018                Babeș-Bolyai University
# 1019                Henan Normal University
# 1020          Southwest Jiaotong University
#
# [2480 rows x 1 columns]

# %% [markdown]
# Si calcola il numero di ranking in cui ogni università appare

# %%
unione.groupby('university')["university"].count().reset_index(name="count")
# Out:
#                                     university  count
# 0     AGH University of Science and Technology      2
# 1                           Aalborg University      3
# 2                             Aalto University      3
# 3                            Aarhus University      3
# 4                       Aberystwyth University      2
# ...                                        ...    ...
# 1353                    École centrale de Lyon      1
# 1354                  École normale supérieure      1
# 1355        École normale supérieure de Cachan      1
# 1356          École normale supérieure de Lyon      1
# 1357                         Örebro University      2
#
# [1358 rows x 2 columns]

# %% [markdown]
# ## 11. In the times ranking, compute the number of times each university appears

# %%
times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %% [markdown]
# Si raggruppa per 'university_name'

# %%
times_appears=times.groupby('university_name')['university_name'].size().reset_index(name='size')
times_appears
# Out:
#                               university_name  size
# 0    AGH University of Science and Technology     1
# 1                          Aalborg University     5
# 2                            Aalto University     5
# 3                           Aarhus University     6
# 4                      Aberystwyth University     5
# ..                                        ...   ...
# 813                  École Normale Supérieure     6
# 814          École Normale Supérieure de Lyon     6
# 815                       École Polytechnique     6
# 816  École Polytechnique Fédérale de Lausanne     6
# 817                         Örebro University     1
#
# [818 rows x 2 columns]

# %% [markdown]
# ## 12.Find the universities that appear at most twice in the times ranking.

# %%
times_appears[times_appears['size']<3]
# Out:
#                               university_name  size
# 0    AGH University of Science and Technology     1
# 5                  Adam Mickiewicz University     1
# 6                    Aix-Marseille University     1
# 7                             Ajou University     1
# 9              Alexandru Ioan Cuza University     1
# ..                                        ...   ...
# 806                  Yokohama City University     1
# 807              Yokohama National University     1
# 810                        Yuan Ze University     2
# 811               Yıldız Technical University     1
# 817                         Örebro University     1
#
# [408 rows x 2 columns]

# %% [markdown]
# ## 13.The universities that, in any year, have the same position in all three rankings (they must have the same position in a year)

# %% [markdown]
# Si effettua una merge intermedia tra shanghai e times sulle colonne 'year' e 'university_name'

# %%
fuso=pd.merge(shanghai[['university_name','world_rank','year']],times[['university_name','world_rank','year']],on=['year','university_name'],suffixes=("_shanghai",""))
fuso.head()
# Out:
#                          university_name world_rank_shanghai  year world_rank
# 0                     Harvard University                   1  2011          1
# 1                    Stanford University                   2  2011          4
# 2  Massachusetts Institute of Technology                   3  2011          3
# 3     University of California, Berkeley                   4  2011          8
# 4                University of Cambridge                   5  2011          6

# %%
cwur.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %% [markdown]
# Si rinomina la colonna 'institution' per maggiore chiarezza

# %%
cwur.rename(columns={'institution':'university_name'}, inplace=True)

# %% [markdown]
# Si effettua una ulteriore merge tra fuso e cwur sulle colonne 'year' e 'university_name'

# %%
ranks=pd.merge(fuso,cwur[['university_name','world_rank',"year"]],on=['year',"university_name"],suffixes=("_times","_cwur"))
ranks
# Out:
#                            university_name world_rank_shanghai  year  \
# 0                       Harvard University                   1  2012
# 1                      Stanford University                   2  2012
# 2    Massachusetts Institute of Technology                   3  2012
# 3       University of California, Berkeley                   4  2012
# 4                  University of Cambridge                   5  2012
# ..                                     ...                 ...   ...
# 654                 University of Oklahoma             401-500  2015
# 655                    University of Pavia             401-500  2015
# 656                  University of Trieste             401-500  2015
# 657        Vienna University of Technology             401-500  2015
# 658                 Wake Forest University             401-500  2015
#
#     world_rank_times  world_rank_cwur
# 0                  2                1
# 1                  2                3
# ...

# %% [markdown]
# Si convertono in float i valori

# %%
ranks["world_rank_shanghai"]=pd.to_numeric(ranks["world_rank_shanghai"],errors='coerce')
ranks["world_rank_cwur"]=pd.to_numeric(ranks["world_rank_cwur"],errors='coerce')
ranks["world_rank_times"]=pd.to_numeric(ranks["world_rank_times"],errors='coerce')

# %% [markdown]
# Si selezionano solo le università che presentano lo stesso ranking nello stesso anno

# %%
same_rank = ranks[(ranks['world_rank_times'] == ranks['world_rank_shanghai']) & (ranks['world_rank_times'] == ranks['world_rank_cwur'])]
same_rank
# Out:
#         university_name  world_rank_shanghai  year  world_rank_times  \
# 71  Stanford University                  2.0  2013               2.0
#
#     world_rank_cwur
# 71                2
